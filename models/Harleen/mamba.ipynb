# %%
import os
import math
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

from copy        import deepcopy
from scipy       import stats
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn            as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

warnings.filterwarnings("ignore")

# %%
INPUT_FILE = "../../data/merged_features_weekly.csv"

TARGET   = "target_price"
LOOKBACK = 52
HORIZON  = 1

FEATURE_COLS = [
    "api_energy_and_lubricants",
    "api_fertilisers_and_soil_improvers",
    "api_plant_protection_products",
    "api_fresh_fruit",
    "api_fresh_vegetables",
    "fuel_petrol_price",
    "fuel_diesel_price",
    "sppi_road_freight",
    "shock_2021q4_2023q1",
    "post_shock",
    "week_sin",
    "week_cos",
]

D_MODEL  = 64
D_STATE  = 16
D_CONV   = 4
EXPAND   = 2
N_LAYERS = 3
DROPOUT  = 0.1

BATCH_SIZE = 32
EPOCHS     = 150
LR         = 1e-3
PATIENCE   = 20
SEED       = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {DEVICE}")
torch.manual_seed(SEED)
np.random.seed(SEED)
# Out:
# Device: cpu

# %%
try:
    from mamba_ssm import Mamba as _OfficialMamba
    _HAVE_MAMBA_SSM = True
    print("mamba-ssm found — using optimised CUDA kernel")
except ImportError:
    _HAVE_MAMBA_SSM = False
    print("mamba-ssm not installed — using pure-PyTorch selective SSM")


class SelectiveSSM(nn.Module):
    def __init__(self, d_inner: int, d_state: int):
        super().__init__()
        self.d_inner = d_inner
        self.d_state = d_state
        self.x_proj  = nn.Linear(d_inner, d_state * 2 + d_inner, bias=False)
        self.dt_proj = nn.Linear(d_inner, d_inner, bias=True)
        A_log        = torch.arange(1, d_state + 1, dtype=torch.float32).log()
        self.A_log   = nn.Parameter(A_log.repeat(d_inner, 1))
        self.D       = nn.Parameter(torch.ones(d_inner))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B, L, d = x.shape
        N = self.d_state
        xz    = self.x_proj(x)
        B_ssm = xz[..., :N]
        C_ssm = xz[..., N : 2 * N]
        dt    = F.softplus(self.dt_proj(xz[..., 2 * N :]))
        A     = -self.A_log.exp()
        A_bar = torch.exp(dt.unsqueeze(-1) * A)
        B_bar = dt.unsqueeze(-1) * B_ssm.unsqueeze(2)
        h  = torch.zeros(B, d, N, device=x.device, dtype=x.dtype)
        ys = []
        for t in range(L):
            h  = A_bar[:, t] * h + B_bar[:, t] * x[:, t].unsqueeze(-1)
            yt = (h * C_ssm[:, t].unsqueeze(1)).sum(-1)
            ys.append(yt)
        return torch.stack(ys, dim=1) + self.D * x


class MambaBlock(nn.Module):
    def __init__(self, d_model: int, d_state: int, d_conv: int, expand: int):
        super().__init__()
        d_inner       = int(d_model * expand)
        self.norm     = nn.LayerNorm(d_model)
        self.in_proj  = nn.Linear(d_model, d_inner * 2, bias=False)
        self.conv1d   = nn.Conv1d(
            d_inner, d_inner, d_conv,
            padding=d_conv - 1, groups=d_inner, bias=True
        )
        self.ssm      = SelectiveSSM(d_inner, d_state)
        self.out_proj = nn.Linear(d_inner, d_model, bias=False)
        self._use_official = False
        if _HAVE_MAMBA_SSM:
            try:
                self._official     = _OfficialMamba(d_model=d_model, d_state=d_state,
                                                    d_conv=d_conv,   expand=expand)
                self._use_official = True
            except Exception:
                pass

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        residual = x
        x = self.norm(x)
        if self._use_official:
            return self._official(x) + residual
        xz      = self.in_proj(x)
        x_in, z = xz.chunk(2, dim=-1)
        x_c = self.conv1d(x_in.transpose(1, 2))
        x_c = x_c[..., : x_in.shape[1]].transpose(1, 2)
        x_c = F.silu(x_c)
        y   = self.ssm(x_c)
        y   = y * F.silu(z)
        return self.out_proj(y) + residual


class MambaForecaster(nn.Module):
    def __init__(self, n_vars, seq_len, horizon,
                 d_model=64, d_state=16, d_conv=4,
                 expand=2, n_layers=3, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(n_vars, d_model)
        self.blocks     = nn.ModuleList([
            MambaBlock(d_model, d_state, d_conv, expand)
            for _ in range(n_layers)
        ])
        self.dropout  = nn.Dropout(dropout)
        self.norm_out = nn.LayerNorm(d_model)
        self.head     = nn.Sequential(
            nn.Linear(d_model, d_model * 2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model * 2, horizon),
        )

    def forward(self, x):
        x = self.input_proj(x)
        for block in self.blocks:
            x = block(x)
        x = self.norm_out(x)
        x = self.dropout(x)
        return self.head(x[:, -1, :])
# Out:
# mamba-ssm not installed — using pure-PyTorch selective SSM

# %%
class TSDataset(Dataset):
    def __init__(self, X: np.ndarray, y: np.ndarray, lookback: int, horizon: int):
        self.X, self.y   = X, y
        self.lookback    = lookback
        self.horizon     = horizon

    def __len__(self):
        return len(self.X) - self.lookback - self.horizon + 1

    def __getitem__(self, idx):
        x = self.X[idx : idx + self.lookback]
        y = self.y[idx + self.lookback : idx + self.lookback + self.horizon]
        return (
            torch.tensor(x, dtype=torch.float32),
            torch.tensor(y, dtype=torch.float32),
        )

# %%
class TSDataset(Dataset):
    def __init__(self, X: np.ndarray, y: np.ndarray, lookback: int, horizon: int):
        self.X        = torch.tensor(X, dtype=torch.float32)
        self.y        = torch.tensor(y, dtype=torch.float32)
        self.lookback = lookback
        self.horizon  = horizon

    def __len__(self):
        return len(self.y) - self.lookback - self.horizon + 1

    def __getitem__(self, idx):
        x_seq = self.X[idx : idx + self.lookback]
        y_val = self.y[idx + self.lookback : idx + self.lookback + self.horizon]
        return x_seq, y_val

# %%
def train_epoch(model, loader, opt, criterion, device):
    model.train()
    total = 0.0
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        opt.zero_grad()
        loss = criterion(model(xb), yb)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        opt.step()
        total += loss.item() * len(xb)
    return total / len(loader.dataset)


@torch.no_grad()
def eval_epoch(model, loader, criterion, device):
    model.eval()
    total, preds, actuals = 0.0, [], []
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        out    = model(xb)
        total += criterion(out, yb).item() * len(xb)
        preds.append(out.cpu().numpy())
        actuals.append(yb.cpu().numpy())
    return (
        total / len(loader.dataset),
        np.concatenate(preds).flatten(),
        np.concatenate(actuals).flatten(),
    )


@torch.no_grad()
def walk_forward(model, X_ctx, n_test, lookback, device):
    model.eval()
    preds = []
    for i in range(n_test):
        window = X_ctx[i : i + lookback]
        xb     = torch.tensor(window, dtype=torch.float32).unsqueeze(0).to(device)
        preds.append(model(xb).cpu().numpy().flatten()[0])
    return np.array(preds)

# %%
def compute_metrics(actual, pred, train, label):
    a, p      = actual.flatten(), pred.flatten()
    naive_mae = np.mean(np.abs(np.diff(train)))
    return {
        "model": label,
        "RMSE" : round(float(np.sqrt(np.mean((a - p) ** 2))),                         4),
        "MAE"  : round(float(np.mean(np.abs(a - p))),                                 4),
        "MASE" : round(float(np.mean(np.abs(a - p)) / naive_mae),                     4),
        "sMAPE": round(float(np.mean(200 * np.abs(a - p) / (np.abs(a) + np.abs(p)))), 4),
        "MAPE" : round(float(np.mean(np.abs((a - p) / a)) * 100),                     4),
    }

# %%
def show_training_curve(tr_losses, vl_losses, best_ep, label):
    fig, ax = plt.subplots(figsize=(10, 4))
    ax.plot(tr_losses, color="#2c3e50", linewidth=1.5, label="Train")
    ax.plot(vl_losses, color="#e74c3c", linewidth=1.5, label="Validation")
    ax.axvline(best_ep, color="#27ae60", linestyle="--",
               label=f"Best epoch ({best_ep})")
    ax.set_title(f"Training Curve — {label}", fontweight="bold", fontsize=13)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("MSE Loss")
    ax.legend()
    plt.tight_layout()
    plt.show()


def show_forecast_plot(dates_train, train_vals,
                       dates_test,  test_vals, pred_vals, label):
    cutoff = dates_train[-1] - pd.Timedelta(weeks=104)
    mask   = dates_train >= cutoff
    fig, ax = plt.subplots(figsize=(13, 5))
    ax.plot(dates_train[mask], train_vals[mask],
            color="#bdc3c7", linewidth=0.9, label="Train")
    ax.plot(dates_test, test_vals,
            color="#2c3e50", linewidth=1.2, label="Actual")
    ax.plot(dates_test, pred_vals,
            color="#e74c3c", linewidth=1.2, linestyle="--", label="Mamba forecast")
    ax.set_title(f"Mamba Forecast — {label}", fontweight="bold", fontsize=13)
    ax.set_ylabel("Price")
    ax.legend(loc="upper left")
    plt.tight_layout()
    plt.show()


def show_residual_diagnostics(residuals, fitted_vals, label):
    resid = residuals
    ci    = 1.96 / np.sqrt(len(resid))

    fig = plt.figure(figsize=(14, 12))
    gs  = gridspec.GridSpec(3, 2, figure=fig, hspace=0.45, wspace=0.35)

    ax1 = fig.add_subplot(gs[0, 0])
    ax1.plot(resid, color="#2c3e50", linewidth=0.6)
    ax1.axhline(0, color="red", linestyle="--")
    ax1.set_title("Residuals over time")
    ax1.set_xlabel("Index"); ax1.set_ylabel("Residual")

    ax2 = fig.add_subplot(gs[0, 1])
    ax2.hist(resid, bins=40, density=True, color="#3498db", alpha=0.7, edgecolor="white")
    xr  = np.linspace(resid.min(), resid.max(), 200)
    ax2.plot(xr, stats.norm.pdf(xr, resid.mean(), resid.std()),
             color="red", linewidth=1.5)
    ax2.set_title("Residual distribution")
    ax2.set_xlabel("Residual"); ax2.set_ylabel("Density")

    ax3  = fig.add_subplot(gs[1, 0])
    lags = min(52, len(resid) // 2 - 1)
    acf  = [np.corrcoef(resid[:-k], resid[k:])[0, 1] for k in range(1, lags + 1)]
    ax3.stem(range(1, lags + 1), acf, basefmt=" ", linefmt="#2980b9", markerfmt="o")
    ax3.axhline( ci, color="red", linestyle="--")
    ax3.axhline(-ci, color="red", linestyle="--")
    ax3.axhline(0, color="black", linewidth=0.6)
    ax3.set_title("ACF of residuals")
    ax3.set_xlabel("Lag"); ax3.set_ylabel("ACF")

    ax4 = fig.add_subplot(gs[1, 1])
    try:
        from statsmodels.tsa.stattools import pacf as sm_pacf
        pv = sm_pacf(resid, nlags=lags, method="ywmle")
        ax4.stem(range(1, len(pv)), pv[1:], basefmt=" ",
                 linefmt="#8e44ad", markerfmt="o")
        ax4.axhline( ci, color="red", linestyle="--")
        ax4.axhline(-ci, color="red", linestyle="--")
        ax4.axhline(0, color="black", linewidth=0.6)
    except Exception:
        ax4.text(0.5, 0.5, "PACF unavailable", ha="center", va="center",
                 transform=ax4.transAxes)
    ax4.set_title("PACF of residuals")
    ax4.set_xlabel("Lag"); ax4.set_ylabel("PACF")

    ax5 = fig.add_subplot(gs[2, 0])
    (osm, osr), (slope, intercept, _) = stats.probplot(resid, dist="norm")
    ax5.scatter(osm, osr, alpha=0.4, s=8, color="#2c3e50")
    ax5.plot(osm, slope * np.array(osm) + intercept, color="red", linewidth=1.5)
    ax5.set_title("Q-Q plot")
    ax5.set_xlabel("Theoretical quantiles"); ax5.set_ylabel("Sample quantiles")

    ax6 = fig.add_subplot(gs[2, 1])
    ax6.scatter(fitted_vals, resid, alpha=0.35, s=8, color="#16a085")
    ax6.axhline(0, color="red", linestyle="--")
    try:
        from statsmodels.nonparametric.smoothers_lowess import lowess
        sm = lowess(resid, fitted_vals, frac=0.3)
        ax6.plot(sm[:, 0], sm[:, 1], color="#e67e22", linewidth=1.5)
    except Exception:
        pass
    ax6.set_title("Residuals vs Fitted")
    ax6.set_xlabel("Fitted"); ax6.set_ylabel("Residual")

    fig.suptitle(
        f"Residual Diagnostics — {label}\n"
        "Row 1: Time series & distribution  |  Row 2: ACF & PACF  |  Row 3: Q-Q & Residuals vs Fitted",
        fontsize=13, fontweight="bold"
    )
    plt.tight_layout()
    plt.show()


def print_residual_tests(residuals, label):
    from statsmodels.stats.diagnostic import acorr_ljungbox
    from scipy.stats import shapiro, anderson

    print(f"\n  {'─'*50}")
    print(f"  Residual diagnostics: {label}")
    print(f"  {'─'*50}")
    print(f"  Mean : {residuals.mean():.6f}")
    print(f"  SD   : {residuals.std():.4f}")

    try:
        lb = acorr_ljungbox(residuals, lags=[10, 20], return_df=True)
        for lag_val, row in lb.iterrows():
            flag = "✗ autocorrelated" if row["lb_pvalue"] < 0.05 else "✓ no autocorrelation"
            print(f"  Ljung-Box lag {int(lag_val):>2}: p={row['lb_pvalue']:.4f}  {flag}")
    except Exception as e:
        print(f"  Ljung-Box: {e}")

    if len(residuals) <= 5000:
        stat, p = shapiro(residuals)
        name    = "Shapiro-Wilk"
    else:
        res  = anderson(residuals, dist="norm")
        stat = res.statistic
        p    = 0.05 if res.statistic > res.critical_values[2] else 0.10
        name = "Anderson-Darling"
    flag = "✗ non-normal" if p < 0.05 else "✓ approximately normal"
    print(f"  {name}: stat={stat:.4f}, p≈{p:.4f}  {flag}")

# %%
def run_commodity(comm: str, sub: pd.DataFrame):
    print(f"\n{'='*60}\n  Commodity: {comm}\n{'='*60}")

    sub = sub.sort_values("date").reset_index(drop=True)

    if "split" not in sub.columns:
        raise ValueError("'split' column not found. Expected values: 'train' / 'test'.")

    train_sub = sub[sub["split"] == "train"].reset_index(drop=True)
    test_sub  = sub[sub["split"] == "test"].reset_index(drop=True)
    n_train   = len(train_sub)
    n_test    = len(test_sub)

    if n_train < LOOKBACK + 30:
        print("  !! Not enough training rows — skipping."); return None
    if n_test == 0:
        print("  !! No test rows found — skipping."); return None

    avail    = [c for c in FEATURE_COLS
                if c in sub.columns and train_sub[c].notna().sum() > LOOKBACK]
    all_cols = [TARGET] + [f for f in avail if f != TARGET]
    n_vars   = len(all_cols)
    print(f"  Variates ({n_vars}): {all_cols}")

    train_data = train_sub[all_cols].copy().ffill().fillna(train_sub[all_cols].mean()).values
    test_data  = test_sub[all_cols].copy().ffill().fillna(train_sub[all_cols].mean()).values

    # Context window: last LOOKBACK rows of train + all test rows
    test_ctx = np.concatenate([train_data[-LOOKBACK:], test_data], axis=0)

    print(f"  Train: {train_sub['date'].iloc[0]} -> {train_sub['date'].iloc[-1]} ({n_train} weeks)")
    print(f"  Test:  {test_sub['date'].iloc[0]}  -> {test_sub['date'].iloc[-1]}  ({n_test} weeks)")

    feat_scaler = StandardScaler().fit(train_data)
    tgt_scaler  = StandardScaler().fit(train_data[:, [0]])

    train_sc = feat_scaler.transform(train_data)
    test_sc  = feat_scaler.transform(test_ctx)

    n_val = max(int(n_train * 0.15), LOOKBACK + 5)
    n_tr  = n_train - n_val

    train_ds = TSDataset(train_sc[:n_tr],              train_sc[:n_tr, 0],              LOOKBACK, HORIZON)
    val_ds   = TSDataset(train_sc[n_tr - LOOKBACK:],   train_sc[n_tr - LOOKBACK:, 0],  LOOKBACK, HORIZON)

    if len(train_ds) < 2 or len(val_ds) < 2:
        print("  !! Dataset windows too small — skipping."); return None

    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  drop_last=False)
    val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

    model = MambaForecaster(
        n_vars=n_vars, seq_len=LOOKBACK, horizon=HORIZON,
        d_model=D_MODEL, d_state=D_STATE, d_conv=D_CONV,
        expand=EXPAND,   n_layers=N_LAYERS, dropout=DROPOUT,
    ).to(DEVICE)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"  Parameters: {n_params:,}")

    opt       = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=EPOCHS)
    criterion = nn.MSELoss()

    best_val, best_state, patience_cnt = float("inf"), None, 0
    tr_losses, vl_losses               = [], []

    print(f"\n  Training up to {EPOCHS} epochs (patience={PATIENCE})...")
    for epoch in range(1, EPOCHS + 1):
        tl       = train_epoch(model, train_loader, opt, criterion, DEVICE)
        vl, _, _ = eval_epoch(model, val_loader,   criterion, DEVICE)
        scheduler.step()
        tr_losses.append(tl); vl_losses.append(vl)

        if vl < best_val:
            best_val, best_state, patience_cnt = vl, deepcopy(model.state_dict()), 0
        else:
            patience_cnt += 1

        if epoch % 10 == 0 or epoch == 1:
            print(f"  Epoch {epoch:>3}  train={tl:.5f}  val={vl:.5f}  best={best_val:.5f}")
        if patience_cnt >= PATIENCE:
            print(f"  Early stopping at epoch {epoch}"); break

    best_ep = int(np.argmin(vl_losses))
    model.load_state_dict(best_state)

    pred_sc   = walk_forward(model, test_sc, n_test, LOOKBACK, DEVICE)
    pred_orig = tgt_scaler.inverse_transform(pred_sc.reshape(-1, 1)).flatten()
    actual    = test_sub[TARGET].values
    train_orig= train_sub[TARGET].values

    min_len   = min(len(pred_orig), len(actual))
    pred_orig = pred_orig[:min_len]
    actual    = actual[:min_len]

    metrics = compute_metrics(actual, pred_orig, train_orig, f"{comm} — Mamba")
    print(f"\n  METRICS:")
    for k, v in metrics.items():
        if k != "model":
            print(f"    {k:<8}: {v}")

    residuals   = actual - pred_orig
    dates_train = pd.to_datetime(train_sub["date"].values)
    dates_test  = pd.to_datetime(test_sub["date"].values[:min_len])

    print_residual_tests(residuals, f"{comm} — Mamba")

    show_training_curve(tr_losses, vl_losses, best_ep, f"{comm} — Mamba")
    show_forecast_plot(dates_train, train_orig, dates_test, actual, pred_orig, f"{comm} — Mamba")
    show_residual_diagnostics(residuals, pred_orig, f"{comm} — Mamba")

    return metrics

# %%
df = (
    pd.read_csv(INPUT_FILE, parse_dates=["date"])
    .sort_values(["commodity", "date"])
    .reset_index(drop=True)
)

commodities = df["commodity"].unique()
print(f"Commodities : {list(commodities)}")
print(f"Device      : {DEVICE}")
print(f"Lookback    : {LOOKBACK} weeks")

all_metrics = []
for comm in commodities:
    result = run_commodity(comm, df[df["commodity"] == comm].copy())
    if result:
        all_metrics.append(result)

if all_metrics:
    summary = pd.DataFrame(all_metrics)
    print("\n\n" + "=" * 60)
    print("  FINAL METRICS SUMMARY")
    print("=" * 60)
    print(summary.to_string(index=False))
    summary.to_csv(os.path.join("outputs", "mamba_metrics.csv"), index=False)
    print("\n✅ Done. mamba_metrics.csv saved.")
# Out:
# Commodities : ['Asparagus', 'Beetroot', 'Bulb Onions (Red)', 'Bulb Onions (Yellow)', 'Cabbage', 'Capsicums (Green)', 'Capsicums (Red)', 'Carrots', 'Cooking Apples', 'Cucumbers', 'Curly kale', 'Dessert Apples', 'Leeks', 'Lettuce', 'Pak choi', 'Pears', 'Spring greens', 'Strawberries', 'Tomatoes (Round)', 'Tomatoes (Vine)']
# Device      : cpu
# Lookback    : 52 weeks  |  Test set: 52 weeks
#
# ============================================================
#   Commodity: Asparagus
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2017-06-30 00:00:00 -> 2024-07-12 00:00:00 (117 weeks)
#   Test:  2025-03-03 00:00:00  -> 2025-06-23 00:00:00  (9 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.31164  val=0.91648  best=0.91648
#   Epoch  10  train=0.04680  val=0.75416  best=0.75416
#   Epoch  20  train=0.00557  val=0.73648  best=0.73463
#   Epoch  30  train=0.01088  val=0.72335  best=0.72335
#   Epoch  40  train=0.02862  val=0.72043  best=0.71806
#   Epoch  50  train=0.01410  val=0.72573  best=0.71806
#   Early stopping at epoch 52
#
#   METRICS:
#     RMSE    : 4.7572
#     MAE     : 4.025
#     MASE    : 2.4806
#     sMAPE   : 29.3544
#     MAPE    : 27.8543
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Asparagus — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 2.070977
#   SD   : 4.2827
#   Ljung-Box: operands could not be broadcast together with shapes (8,) (20,)
#   Shapiro-Wilk: stat=0.9673, p≈0.8704  ✓ approximately normal
#   Saved all plots for: Asparagus
#
# ============================================================
#   Commodity: Beetroot
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (446 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.50594  val=0.17205  best=0.17205
#   Epoch  10  train=0.05182  val=0.25363  best=0.17205
#   Epoch  20  train=0.05034  val=0.28736  best=0.17205
#   Early stopping at epoch 21
#
#   METRICS:
#     RMSE    : 0.1237
#     MAE     : 0.1161
#     MASE    : 6.1476
#     sMAPE   : 17.0594
#     MAPE    : 15.6004
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Beetroot — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.116139
#   SD   : 0.0425
#   Ljung-Box lag 10: p=0.5686  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.7506  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9170, p≈0.0293  ✗ non-normal
#   Saved all plots for: Beetroot
#
# ============================================================
#   Commodity: Bulb Onions (Red)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (426 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.38620  val=1.41221  best=1.41221
#   Epoch  10  train=0.09776  val=1.13948  best=1.01086
#   Epoch  20  train=0.05551  val=1.23131  best=1.01086
#   Early stopping at epoch 25
#
#   METRICS:
#     RMSE    : 0.0936
#     MAE     : 0.0594
#     MASE    : 1.4269
#     sMAPE   : 8.2935
#     MAPE    : 7.9071
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Bulb Onions (Red) — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.037191
#   SD   : 0.0859
#   Ljung-Box lag 10: p=0.3981  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.7778  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.8075, p≈0.0001  ✗ non-normal
#   Saved all plots for: Bulb Onions (Red)
#
# ============================================================
#   Commodity: Bulb Onions (Yellow)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (439 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.66452  val=0.29884  best=0.29884
#   Epoch  10  train=0.10370  val=0.68593  best=0.29884
#   Epoch  20  train=0.06236  val=0.73197  best=0.29884
#   Early stopping at epoch 21
#
#   METRICS:
#     RMSE    : 0.1055
#     MAE     : 0.0821
#     MASE    : 2.1581
#     sMAPE   : 13.8445
#     MAPE    : 15.6558
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Bulb Onions (Yellow) — Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.077145
#   SD   : 0.0720
#   Ljung-Box lag 10: p=0.0004  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0000  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9592, p≈0.3336  ✓ approximately normal
#   Saved all plots for: Bulb Onions (Yellow)
#
# ============================================================
#   Commodity: Cabbage
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (447 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.45981  val=0.35680  best=0.35680
#   Epoch  10  train=0.05518  val=0.31716  best=0.26113
#   Epoch  20  train=0.04067  val=0.17613  best=0.15646
#   Epoch  30  train=0.03318  val=0.16657  best=0.14097
#   Epoch  40  train=0.02716  val=0.20113  best=0.14097
#   Early stopping at epoch 43
#
#   METRICS:
#     RMSE    : 0.0468
#     MAE     : 0.0372
#     MASE    : 1.7264
#     sMAPE   : 5.3204
#     MAPE    : 5.4842
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Cabbage — Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.020476
#   SD   : 0.0421
#   Ljung-Box lag 10: p=0.0042  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0001  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9708, p≈0.6018  ✓ approximately normal
#   Saved all plots for: Cabbage
#
# ============================================================
#   Commodity: Capsicums (Green)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2018-07-27 00:00:00 -> 2024-11-08 00:00:00 (120 weeks)
#   Test:  2025-04-14 00:00:00  -> 2025-10-13 00:00:00  (14 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.76592  val=1.27912  best=1.27912
#   Epoch  10  train=0.18805  val=1.33560  best=1.24044
#   Epoch  20  train=0.17469  val=1.54455  best=1.24044
#   Early stopping at epoch 24
#
#   METRICS:
#     RMSE    : 0.3978
#     MAE     : 0.3331
#     MASE    : 1.356
#     sMAPE   : 22.7071
#     MAPE    : 24.2145
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Capsicums (Green) — Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.092249
#   SD   : 0.3870
#   Ljung-Box: operands could not be broadcast together with shapes (13,) (20,)
#   Shapiro-Wilk: stat=0.8196, p≈0.0088  ✗ non-normal
#   Saved all plots for: Capsicums (Green)
#
# ============================================================
#   Commodity: Capsicums (Red)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2017-09-08 00:00:00 -> 2024-11-08 00:00:00 (191 weeks)
#   Test:  2025-04-14 00:00:00  -> 2025-11-10 00:00:00  (14 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.79256  val=1.08665  best=1.08665
#   Epoch  10  train=0.26632  val=0.63929  best=0.63190
#   Epoch  20  train=0.11406  val=0.72719  best=0.63190
#   Early stopping at epoch 29
#
#   METRICS:
#     RMSE    : 0.7114
#     MAE     : 0.4355
#     MASE    : 1.8616
#     sMAPE   : 29.9888
#     MAPE    : 27.2008
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Capsicums (Red) — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.188536
#   SD   : 0.6859
#   Ljung-Box: operands could not be broadcast together with shapes (13,) (20,)
#   Shapiro-Wilk: stat=0.8123, p≈0.0071  ✗ non-normal
#   Saved all plots for: Capsicums (Red)
#
# ============================================================
#   Commodity: Carrots
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (438 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.52694  val=0.42755  best=0.42755
#   Epoch  10  train=0.04578  val=0.18176  best=0.12207
#   Epoch  20  train=0.03494  val=0.12620  best=0.12207
#   Early stopping at epoch 28
#
#   METRICS:
#     RMSE    : 0.0698
#     MAE     : 0.0535
#     MASE    : 2.7982
#     sMAPE   : 9.4392
#     MAPE    : 10.1297
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Carrots — Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.040051
#   SD   : 0.0572
#   Ljung-Box lag 10: p=0.1319  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.0726  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9544, p≈0.2550  ✓ approximately normal
#   Saved all plots for: Carrots
#
# ============================================================
#   Commodity: Cooking Apples
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (446 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.59895  val=0.40927  best=0.40927
#   Epoch  10  train=0.08913  val=0.27411  best=0.21954
#   Epoch  20  train=0.06705  val=0.31809  best=0.21954
#   Early stopping at epoch 23
#
#   METRICS:
#     RMSE    : 0.1695
#     MAE     : 0.144
#     MASE    : 2.1135
#     sMAPE   : 11.6754
#     MAPE    : 10.8547
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Cooking Apples — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.119390
#   SD   : 0.1203
#   Ljung-Box lag 10: p=0.0000  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0000  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9351, p≈0.0829  ✓ approximately normal
#   Saved all plots for: Cooking Apples
#
# ============================================================
#   Commodity: Cucumbers
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-05-20 00:00:00 -> 2024-12-20 00:00:00 (342 weeks)
#   Test:  2025-01-20 00:00:00  -> 2025-11-24 00:00:00  (21 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.72228  val=0.81275  best=0.81275
#   Epoch  10  train=0.39367  val=0.70798  best=0.60167
#   Epoch  20  train=0.15101  val=0.87953  best=0.60167
#   Early stopping at epoch 25
#
#   METRICS:
#     RMSE    : 0.1934
#     MAE     : 0.1574
#     MASE    : 1.2474
#     sMAPE   : 15.6991
#     MAPE    : 15.1673
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Cucumbers — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.079898
#   SD   : 0.1762
#   Ljung-Box lag 10: p=0.5333  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.6026  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9806, p≈0.9332  ✓ approximately normal
#   Saved all plots for: Cucumbers
#
# ============================================================
#   Commodity: Curly kale
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2018-11-16 00:00:00 -> 2024-12-20 00:00:00 (301 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.32413  val=0.48141  best=0.48141
#   Epoch  10  train=0.04481  val=0.26241  best=0.18476
#   Epoch  20  train=0.03290  val=0.24977  best=0.18476
#   Early stopping at epoch 24
#
#   METRICS:
#     RMSE    : 0.3653
#     MAE     : 0.2923
#     MASE    : 2.1947
#     sMAPE   : 6.7146
#     MAPE    : 6.6615
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Curly kale — Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.003753
#   SD   : 0.3653
#   Ljung-Box lag 10: p=0.0000  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0000  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9548, p≈0.2612  ✓ approximately normal
#   Saved all plots for: Curly kale
#
# ============================================================
#   Commodity: Dessert Apples
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-04-08 00:00:00 -> 2024-12-20 00:00:00 (410 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.41184  val=0.49015  best=0.49015
#   Epoch  10  train=0.14549  val=0.15360  best=0.15360
#   Epoch  20  train=0.07660  val=0.18806  best=0.15360
#   Epoch  30  train=0.03984  val=0.17447  best=0.15360
#   Early stopping at epoch 30
#
#   METRICS:
#     RMSE    : 0.1292
#     MAE     : 0.1087
#     MASE    : 1.6177
#     sMAPE   : 8.7809
#     MAPE    : 8.2777
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Dessert Apples — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.108338
#   SD   : 0.0704
#   Ljung-Box lag 10: p=0.8190  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.7741  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9650, p≈0.4551  ✓ approximately normal
#   Saved all plots for: Dessert Apples
#
# ============================================================
#   Commodity: Leeks
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (425 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.40068  val=0.83460  best=0.83460
#   Epoch  10  train=0.07370  val=0.64577  best=0.58463
#   Epoch  20  train=0.04301  val=0.61593  best=0.58463
#   Early stopping at epoch 29
#
#   METRICS:
#     RMSE    : 0.1134
#     MAE     : 0.0875
#     MASE    : 1.418
#     sMAPE   : 5.6305
#     MAPE    : 5.6901
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Leeks — Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.021708
#   SD   : 0.1113
#   Ljung-Box lag 10: p=0.2875  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.3933  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9601, p≈0.3509  ✓ approximately normal
#   Saved all plots for: Leeks
#
# ============================================================
#   Commodity: Lettuce
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (445 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.44525  val=0.36961  best=0.36961
#   Epoch  10  train=0.07488  val=0.42224  best=0.33611
#   Epoch  20  train=0.07141  val=0.51777  best=0.33611
#   Early stopping at epoch 22
#
#   METRICS:
#     RMSE    : 0.0884
#     MAE     : 0.0787
#     MASE    : 3.4485
#     sMAPE   : 12.0275
#     MAPE    : 11.1956
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Lettuce — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.078695
#   SD   : 0.0404
#   Ljung-Box lag 10: p=0.0186  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0002  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9746, p≈0.7087  ✓ approximately normal
#   Saved all plots for: Lettuce
#
# ============================================================
#   Commodity: Pak choi
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2018-11-16 00:00:00 -> 2024-12-20 00:00:00 (305 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.45602  val=0.39924  best=0.39924
#   Epoch  10  train=0.07603  val=0.18828  best=0.18828
#   Epoch  20  train=0.06010  val=0.19455  best=0.18005
#   Epoch  30  train=0.03558  val=0.18632  best=0.18005
#   Early stopping at epoch 34
#
#   METRICS:
#     RMSE    : 0.2998
#     MAE     : 0.2403
#     MASE    : 1.8236
#     sMAPE   : 7.0121
#     MAPE    : 6.656
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Pak choi — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.232245
#   SD   : 0.1896
#   Ljung-Box lag 10: p=0.0090  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0000  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9591, p≈0.3311  ✓ approximately normal
#   Saved all plots for: Pak choi
#
# ============================================================
#   Commodity: Pears
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-02-26 00:00:00 -> 2024-12-20 00:00:00 (340 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (22 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.53523  val=0.35431  best=0.35431
#   Epoch  10  train=0.15911  val=0.81971  best=0.31079
#   Epoch  20  train=0.11771  val=0.66301  best=0.31079
#   Early stopping at epoch 22
#
#   METRICS:
#     RMSE    : 0.1797
#     MAE     : 0.1303
#     MASE    : 1.2451
#     sMAPE   : 11.8778
#     MAPE    : 13.5076
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Pears — Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.079973
#   SD   : 0.1610
#   Ljung-Box lag 10: p=0.0793  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.5499  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9640, p≈0.5747  ✓ approximately normal
#   Saved all plots for: Pears
#
# ============================================================
#   Commodity: Spring greens
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2018-11-16 00:00:00 -> 2024-12-20 00:00:00 (302 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.69158  val=1.13325  best=1.13325
#   Epoch  10  train=0.08889  val=0.61871  best=0.53208
#   Epoch  20  train=0.08618  val=0.66951  best=0.53208
#   Early stopping at epoch 28
#
#   METRICS:
#     RMSE    : 0.1873
#     MAE     : 0.1455
#     MASE    : 1.9022
#     sMAPE   : 10.3916
#     MAPE    : 9.7595
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Spring greens — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.101173
#   SD   : 0.1576
#   Ljung-Box lag 10: p=0.6819  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.2265  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9498, p≈0.1959  ✓ approximately normal
#   Saved all plots for: Spring greens
#
# ============================================================
#   Commodity: Strawberries
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-07-15 00:00:00 -> 2024-12-13 00:00:00 (286 weeks)
#   Test:  2025-04-14 00:00:00  -> 2025-11-24 00:00:00  (17 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.88405  val=0.43912  best=0.43912
#   Epoch  10  train=0.41042  val=0.75035  best=0.41569
#   Epoch  20  train=0.12618  val=0.87613  best=0.41569
#   Early stopping at epoch 22
#
#   METRICS:
#     RMSE    : 1.5812
#     MAE     : 1.1455
#     MASE    : 1.1805
#     sMAPE   : 21.0015
#     MAPE    : 19.514
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Strawberries — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.782290
#   SD   : 1.3742
#   Ljung-Box: operands could not be broadcast together with shapes (16,) (20,)
#   Shapiro-Wilk: stat=0.8647, p≈0.0181  ✗ non-normal
#   Saved all plots for: Strawberries
#
# ============================================================
#   Commodity: Tomatoes (Round)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-07-15 00:00:00 -> 2024-11-22 00:00:00 (301 weeks)
#   Test:  2025-04-14 00:00:00  -> 2025-12-08 00:00:00  (18 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.08094  val=0.74622  best=0.74622
#   Epoch  10  train=0.34739  val=0.95896  best=0.63903
#   Epoch  20  train=0.11553  val=1.22543  best=0.63903
#   Early stopping at epoch 23
#
#   METRICS:
#     RMSE    : 0.2502
#     MAE     : 0.1987
#     MASE    : 1.0397
#     sMAPE   : 19.4704
#     MAPE    : 17.9448
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Tomatoes (Round) — Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.102445
#   SD   : 0.2283
#   Ljung-Box: operands could not be broadcast together with shapes (17,) (20,)
#   Shapiro-Wilk: stat=0.9516, p≈0.4499  ✓ approximately normal
#   Saved all plots for: Tomatoes (Round)
#
# ============================================================
#   Commodity: Tomatoes (Vine)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-07-22 00:00:00 -> 2024-12-20 00:00:00 (271 weeks)
#   Test:  2025-04-14 00:00:00  -> 2025-12-22 00:00:00  (19 weeks)
#   Parameters: 203,009
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.16721  val=0.95564  best=0.95564
#   Epoch  10  train=0.56505  val=1.13123  best=0.76750
#   Epoch  20  train=0.19362  val=1.44079  best=0.76750
#   Early stopping at epoch 23
#
#   METRICS:
#     RMSE    : 0.4648
#     MAE     : 0.3593
#     MASE    : 1.1745
#     sMAPE   : 23.8289
#     MAPE    : 27.4221
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Tomatoes (Vine) — Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.144055
#   SD   : 0.4419
#   Ljung-Box: operands could not be broadcast together with shapes (18,) (20,)
#   Shapiro-Wilk: stat=0.8662, p≈0.0124  ✗ non-normal
#   Saved all plots for: Tomatoes (Vine)
#
#
# ============================================================
#   FINAL METRICS SUMMARY
# ============================================================
#                        model   RMSE    MAE   MASE   sMAPE    MAPE
#            Asparagus — Mamba 4.7572 4.0250 2.4806 29.3544 27.8543
#             Beetroot — Mamba 0.1237 0.1161 6.1476 17.0594 15.6004
#    Bulb Onions (Red) — Mamba 0.0936 0.0594 1.4269  8.2935  7.9071
# Bulb Onions (Yellow) — Mamba 0.1055 0.0821 2.1581 13.8445 15.6558
#              Cabbage — Mamba 0.0468 0.0372 1.7264  5.3204  5.4842
#    Capsicums (Green) — Mamba 0.3978 0.3331 1.3560 22.7071 24.2145
#      Capsicums (Red) — Mamba 0.7114 0.4355 1.8616 29.9888 27.2008
#              Carrots — Mamba 0.0698 0.0535 2.7982  9.4392 10.1297
#       Cooking Apples — Mamba 0.1695 0.1440 2.1135 11.6754 10.8547
#            Cucumbers — Mamba 0.1934 0.1574 1.2474 15.6991 15.1673
#           Curly kale — Mamba 0.3653 0.2923 2.1947  6.7146  6.6615
#       Dessert Apples — Mamba 0.1292 0.1087 1.6177  8.7809  8.2777
#                Leeks — Mamba 0.1134 0.0875 1.4180  5.6305  5.6901
#              Lettuce — Mamba 0.0884 0.0787 3.4485 12.0275 11.1956
#             Pak choi — Mamba 0.2998 0.2403 1.8236  7.0121  6.6560
#                Pears — Mamba 0.1797 0.1303 1.2451 11.8778 13.5076
#        Spring greens — Mamba 0.1873 0.1455 1.9022 10.3916  9.7595
#         Strawberries — Mamba 1.5812 1.1455 1.1805 21.0015 19.5140
#     Tomatoes (Round) — Mamba 0.2502 0.1987 1.0397 19.4704 17.9448
#      Tomatoes (Vine) — Mamba 0.4648 0.3593 1.1745 23.8289 27.4221
#
# Done. Files saved:
#    mamba_metrics.csv
#    mamba_training_*.png   — loss curves with early-stopping marker
#    mamba_forecast_*.png   — predicted vs actual on 52-week hold-out
#    mamba_residuals_*.png  — 6-panel residual diagnostics
