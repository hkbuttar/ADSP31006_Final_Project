# %%
import os
import math
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from copy  import deepcopy
from scipy import stats
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn            as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
warnings.filterwarnings("ignore")

# %%
INPUT_FILE = "../../data/merged_features_weekly.csv"

TARGET   = "target_price"
LOOKBACK = 52
HORIZON  = 1

FEATURE_COLS = [
    "api_energy_and_lubricants",
    "api_fertilisers_and_soil_improvers",
    "api_plant_protection_products",
    "api_fresh_fruit",
    "api_fresh_vegetables",
    "fuel_petrol_price",
    "fuel_diesel_price",
    "sppi_road_freight",
    "shock_2021q4_2023q1",
    "post_shock",
    "week_sin",
    "week_cos",
]

D_MODEL   = 64
D_STATE   = 16
D_CONV    = 4
EXPAND    = 2
N_LAYERS  = 2
PATCH_LEN = 4
STRIDE    = 2
N_HEADS   = 4
DROPOUT   = 0.1

BATCH_SIZE = 32
EPOCHS     = 150
LR         = 1e-3
PATIENCE   = 20
SEED       = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {DEVICE}")
torch.manual_seed(SEED)
np.random.seed(SEED)
# Out:
# Device: cpu

# %%
try:
    from mamba_ssm import Mamba as _OfficialMamba
    _HAVE_MAMBA_SSM = True
    print("mamba-ssm found — using optimised CUDA kernel")
except ImportError:
    _HAVE_MAMBA_SSM = False
    print("mamba-ssm not installed — using pure-PyTorch selective SSM")


class SelectiveSSM(nn.Module):
    def __init__(self, d_inner: int, d_state: int):
        super().__init__()
        self.d_inner = d_inner
        self.d_state = d_state
        self.x_proj  = nn.Linear(d_inner, d_state * 2 + d_inner, bias=False)
        self.dt_proj = nn.Linear(d_inner, d_inner, bias=True)
        A_log = torch.arange(1, d_state + 1, dtype=torch.float32).log()
        self.A_log = nn.Parameter(A_log.repeat(d_inner, 1))
        self.D     = nn.Parameter(torch.ones(d_inner))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B, L, d = x.shape
        N = self.d_state
        xz    = self.x_proj(x)
        B_ssm = xz[..., :N]
        C_ssm = xz[..., N : 2 * N]
        dt    = F.softplus(self.dt_proj(xz[..., 2 * N :]))
        A     = -self.A_log.exp()
        A_bar = torch.exp(dt.unsqueeze(-1) * A)
        B_bar = dt.unsqueeze(-1) * B_ssm.unsqueeze(2)
        h, ys = torch.zeros(B, d, N, device=x.device, dtype=x.dtype), []
        for t in range(L):
            h  = A_bar[:, t] * h + B_bar[:, t] * x[:, t].unsqueeze(-1)
            ys.append((h * C_ssm[:, t].unsqueeze(1)).sum(-1))
        return torch.stack(ys, dim=1) + self.D * x


class MambaBlock(nn.Module):
    def __init__(self, d_model: int, d_state: int, d_conv: int, expand: int):
        super().__init__()
        d_inner = int(d_model * expand)
        self.norm     = nn.LayerNorm(d_model)
        self.in_proj  = nn.Linear(d_model, d_inner * 2, bias=False)
        self.conv1d   = nn.Conv1d(d_inner, d_inner, d_conv,
                                  padding=d_conv - 1, groups=d_inner, bias=True)
        self.ssm      = SelectiveSSM(d_inner, d_state)
        self.out_proj = nn.Linear(d_inner, d_model, bias=False)
        self._use_official = False
        if _HAVE_MAMBA_SSM:
            try:
                self._official     = _OfficialMamba(d_model=d_model, d_state=d_state,
                                                    d_conv=d_conv,   expand=expand)
                self._use_official = True
            except Exception:
                pass

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        residual = x
        x = self.norm(x)
        if self._use_official:
            return self._official(x) + residual
        xz      = self.in_proj(x)
        x_in, z = xz.chunk(2, dim=-1)
        x_c     = self.conv1d(x_in.transpose(1, 2))[..., : x_in.shape[1]].transpose(1, 2)
        x_c     = F.silu(x_c)
        y       = self.ssm(x_c) * F.silu(z)
        return self.out_proj(y) + residual
# Out:
# mamba-ssm not installed — using pure-PyTorch selective SSM

# %%
class SMamba(nn.Module):
    def __init__(self, n_vars, seq_len, horizon,
                 d_model=64, d_state=16, d_conv=4, expand=2,
                 n_layers=2, patch_len=4, stride=2, n_heads=4, dropout=0.1):
        super().__init__()
        self.n_vars    = n_vars
        self.seq_len   = seq_len
        self.horizon   = horizon
        self.d_model   = d_model
        self.patch_len = patch_len
        self.stride    = stride
        self.n_patches = (seq_len - patch_len) // stride + 1

        self.patch_embed = nn.Linear(patch_len, d_model)
        self.pos_drop    = nn.Dropout(dropout)
        self.register_buffer("pos_enc", self._sinusoidal(self.n_patches, d_model))

        self.inter_mamba = nn.ModuleList([
            MambaBlock(d_model, d_state, d_conv, expand) for _ in range(n_layers)
        ])

        assert d_model % n_heads == 0
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=n_heads, dim_feedforward=d_model * 4,
            dropout=dropout, batch_first=True, norm_first=True,
        )
        self.intra_attn = nn.TransformerEncoder(encoder_layer, num_layers=1)
        self.norm = nn.LayerNorm(d_model)
        self.head = nn.Sequential(
            nn.Flatten(),
            nn.Linear(self.n_patches * d_model, 128),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(128, horizon),
        )

    @staticmethod
    def _sinusoidal(n, d):
        pe  = torch.zeros(n, d)
        pos = torch.arange(n).unsqueeze(1).float()
        div = torch.exp(torch.arange(0, d, 2).float() * (-math.log(10000.0) / d))
        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div)
        return pe.unsqueeze(0)

    def _patchify(self, x):
        patches = [x[:, i * self.stride : i * self.stride + self.patch_len, :]
                   for i in range(self.n_patches)]
        return torch.stack(patches, dim=2).permute(0, 3, 2, 1)

    def forward(self, x):
        B, L, V = x.shape
        P = self.n_patches
        patches = self._patchify(x)
        tokens  = self.patch_embed(patches) + self.pos_enc
        tokens  = self.pos_drop(tokens)
        inter   = tokens.permute(0, 2, 1, 3).reshape(B * P, V, self.d_model)
        for layer in self.inter_mamba:
            inter = layer(inter)
        inter      = inter.reshape(B, P, V, self.d_model).permute(0, 2, 1, 3)
        target_tok = self.intra_attn(inter[:, 0, :, :])
        target_tok = self.norm(target_tok)
        return self.head(target_tok)

# %%
class TSDataset(Dataset):
    def __init__(self, X: np.ndarray, y: np.ndarray, lookback: int, horizon: int):
        self.X        = torch.tensor(X, dtype=torch.float32)
        self.y        = torch.tensor(y, dtype=torch.float32)
        self.lookback = lookback
        self.horizon  = horizon

    def __len__(self):
        return len(self.y) - self.lookback - self.horizon + 1

    def __getitem__(self, idx):
        return (self.X[idx : idx + self.lookback],
                self.y[idx + self.lookback : idx + self.lookback + self.horizon])

# %%
def compute_metrics(actual, pred, train, label):
    a, p      = actual.flatten(), pred.flatten()
    naive_mae = np.mean(np.abs(np.diff(train)))
    return {
        "model": label,
        "RMSE" : round(float(np.sqrt(np.mean((a - p) ** 2))),                          4),
        "MAE"  : round(float(np.mean(np.abs(a - p))),                                  4),
        "MASE" : round(float(np.mean(np.abs(a - p)) / naive_mae),                      4),
        "sMAPE": round(float(np.mean(200 * np.abs(a-p) / (np.abs(a) + np.abs(p)))),    4),
        "MAPE" : round(float(np.mean(np.abs((a - p) / a)) * 100),                      4),
    }

# %%
def train_epoch(model, loader, opt, criterion, device):
    model.train()
    total = 0.0
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        opt.zero_grad()
        loss = criterion(model(xb), yb)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        opt.step()
        total += loss.item() * len(xb)
    return total / len(loader.dataset)


@torch.no_grad()
def eval_epoch(model, loader, criterion, device):
    model.eval()
    total, preds, actuals = 0.0, [], []
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        out    = model(xb)
        total += criterion(out, yb).item() * len(xb)
        preds.append(out.cpu().numpy())
        actuals.append(yb.cpu().numpy())
    return (total / len(loader.dataset),
            np.concatenate(preds).flatten(),
            np.concatenate(actuals).flatten())


@torch.no_grad()
def walk_forward(model, X_ctx: np.ndarray, n_test: int, lookback: int, device: str):
    """One-step-ahead walk-forward — no leakage of future values."""
    model.eval()
    preds = []
    for i in range(n_test):
        xb = torch.tensor(X_ctx[i : i + lookback], dtype=torch.float32).unsqueeze(0).to(device)
        preds.append(model(xb).cpu().numpy().flatten()[0])
    return np.array(preds)

class TSDataset(Dataset):
    def __init__(self, X, y, lookback, horizon):
        self.X        = torch.tensor(X, dtype=torch.float32)
        self.y        = torch.tensor(y, dtype=torch.float32)
        self.lookback = lookback
        self.horizon  = horizon

    def __len__(self):
        return len(self.y) - self.lookback - self.horizon + 1

    def __getitem__(self, idx):
        return (self.X[idx : idx + self.lookback],
                self.y[idx + self.lookback : idx + self.lookback + self.horizon])

# %%
def compute_metrics(actual, pred, train, label):
    a, p      = actual.flatten(), pred.flatten()
    naive_mae = np.mean(np.abs(np.diff(train)))
    return {
        "model": label,
        "RMSE" : round(float(np.sqrt(np.mean((a - p) ** 2))),                          4),
        "MAE"  : round(float(np.mean(np.abs(a - p))),                                  4),
        "MASE" : round(float(np.mean(np.abs(a - p)) / naive_mae),                      4),
        "sMAPE": round(float(np.mean(200 * np.abs(a-p) / (np.abs(a) + np.abs(p)))),    4),
        "MAPE" : round(float(np.mean(np.abs((a - p) / a)) * 100),                      4),
    }

# %%
def train_epoch(model, loader, opt, criterion, device):
    model.train()
    total = 0.0
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        opt.zero_grad()
        loss = criterion(model(xb), yb)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        opt.step()
        total += loss.item() * len(xb)
    return total / len(loader.dataset)


@torch.no_grad()
def eval_epoch(model, loader, criterion, device):
    model.eval()
    total, preds, actuals = 0.0, [], []
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        out    = model(xb)
        total += criterion(out, yb).item() * len(xb)
        preds.append(out.cpu().numpy())
        actuals.append(yb.cpu().numpy())
    return (total / len(loader.dataset),
            np.concatenate(preds).flatten(),
            np.concatenate(actuals).flatten())


@torch.no_grad()
def walk_forward(model, X_ctx, n_test, lookback, device):
    model.eval()
    preds = []
    for i in range(n_test):
        xb = torch.tensor(X_ctx[i : i + lookback], dtype=torch.float32).unsqueeze(0).to(device)
        preds.append(model(xb).cpu().numpy().flatten()[0])
    return np.array(preds)

# %%
def show_training_curve(tr_losses, vl_losses, best_ep, label):
    fig, ax = plt.subplots(figsize=(10, 4))
    ax.plot(tr_losses, color="#2c3e50", linewidth=1.5, label="Train")
    ax.plot(vl_losses, color="#e74c3c", linewidth=1.5, label="Validation")
    ax.axvline(best_ep, color="#27ae60", linestyle="--", label=f"Best epoch ({best_ep})")
    ax.set_title(f"Training Curve — {label}", fontweight="bold", fontsize=13)
    ax.set_xlabel("Epoch"); ax.set_ylabel("MSE Loss")
    ax.legend(); plt.tight_layout(); plt.show()


def show_forecast_plot(dates_train, train_vals, dates_test, test_vals, pred_vals, label):
    cutoff  = dates_train[-1] - pd.Timedelta(weeks=104)
    mask    = dates_train >= cutoff
    fig, ax = plt.subplots(figsize=(13, 5))
    ax.plot(dates_train[mask], train_vals[mask],
            color="#bdc3c7", linewidth=0.9, label="Train")
    ax.plot(dates_test, test_vals,
            color="#2c3e50", linewidth=1.2, label="Actual")
    ax.plot(dates_test, pred_vals,
            color="#e74c3c", linewidth=1.2, linestyle="--", label="S-Mamba forecast")
    ax.set_title(f"S-Mamba Forecast — {label}", fontweight="bold", fontsize=13)
    ax.set_ylabel("Price"); ax.legend(loc="upper left")
    plt.tight_layout(); plt.show()


def show_residual_diagnostics(residuals, fitted_vals, label):
    resid = residuals
    ci    = 1.96 / np.sqrt(len(resid))

    fig = plt.figure(figsize=(14, 12))
    gs  = gridspec.GridSpec(3, 2, figure=fig, hspace=0.45, wspace=0.35)

    ax1 = fig.add_subplot(gs[0, 0])
    ax1.plot(resid, color="#2c3e50", linewidth=0.6)
    ax1.axhline(0, color="red", linestyle="--")
    ax1.set_title("Residuals over time"); ax1.set_xlabel("Index"); ax1.set_ylabel("Residual")

    ax2 = fig.add_subplot(gs[0, 1])
    ax2.hist(resid, bins=40, density=True, color="#3498db", alpha=0.7, edgecolor="white")
    xr  = np.linspace(resid.min(), resid.max(), 200)
    ax2.plot(xr, stats.norm.pdf(xr, resid.mean(), resid.std()), color="red", linewidth=1.5)
    ax2.set_title("Residual distribution"); ax2.set_xlabel("Residual"); ax2.set_ylabel("Density")

    ax3  = fig.add_subplot(gs[1, 0])
    lags = min(52, len(resid) // 2 - 1)
    acf  = [np.corrcoef(resid[:-k], resid[k:])[0, 1] for k in range(1, lags + 1)]
    ax3.stem(range(1, lags + 1), acf, basefmt=" ", linefmt="#2980b9", markerfmt="o")
    ax3.axhline( ci, color="red", linestyle="--")
    ax3.axhline(-ci, color="red", linestyle="--")
    ax3.axhline(0, color="black", linewidth=0.6)
    ax3.set_title("ACF of residuals"); ax3.set_xlabel("Lag"); ax3.set_ylabel("ACF")

    ax4 = fig.add_subplot(gs[1, 1])
    try:
        from statsmodels.tsa.stattools import pacf as sm_pacf
        pv = sm_pacf(resid, nlags=lags, method="ywmle")
        ax4.stem(range(1, len(pv)), pv[1:], basefmt=" ", linefmt="#8e44ad", markerfmt="o")
        ax4.axhline( ci, color="red", linestyle="--")
        ax4.axhline(-ci, color="red", linestyle="--")
        ax4.axhline(0, color="black", linewidth=0.6)
    except Exception:
        ax4.text(0.5, 0.5, "PACF unavailable", ha="center", va="center",
                 transform=ax4.transAxes)
    ax4.set_title("PACF of residuals"); ax4.set_xlabel("Lag"); ax4.set_ylabel("PACF")

    ax5 = fig.add_subplot(gs[2, 0])
    (osm, osr), (slope, intercept, _) = stats.probplot(resid, dist="norm")
    ax5.scatter(osm, osr, alpha=0.4, s=8, color="#2c3e50")
    ax5.plot(osm, slope * np.array(osm) + intercept, color="red", linewidth=1.5)
    ax5.set_title("Q-Q plot"); ax5.set_xlabel("Theoretical quantiles"); ax5.set_ylabel("Sample quantiles")

    ax6 = fig.add_subplot(gs[2, 1])
    ax6.scatter(fitted_vals, resid, alpha=0.35, s=8, color="#16a085")
    ax6.axhline(0, color="red", linestyle="--")
    try:
        from statsmodels.nonparametric.smoothers_lowess import lowess
        sm = lowess(resid, fitted_vals, frac=0.3)
        ax6.plot(sm[:, 0], sm[:, 1], color="#e67e22", linewidth=1.5)
    except Exception:
        pass
    ax6.set_title("Residuals vs Fitted"); ax6.set_xlabel("Fitted"); ax6.set_ylabel("Residual")

    fig.suptitle(
        f"Residual Diagnostics — {label}\n"
        "Row 1: Time series & distribution  |  Row 2: ACF & PACF  |  Row 3: Q-Q & Residuals vs Fitted",
        fontsize=13, fontweight="bold"
    )
    plt.tight_layout(); plt.show()


def print_residual_tests(residuals, label):
    from statsmodels.stats.diagnostic import acorr_ljungbox
    from scipy.stats import shapiro, anderson

    print(f"\n  {'─'*50}")
    print(f"  Residual diagnostics: {label}")
    print(f"  {'─'*50}")
    print(f"  Mean : {residuals.mean():.6f}")
    print(f"  SD   : {residuals.std():.4f}")
    try:
        lb = acorr_ljungbox(residuals, lags=[10, 20], return_df=True)
        for lag_val, row in lb.iterrows():
            flag = "✗ autocorrelated" if row["lb_pvalue"] < 0.05 else "✓ no autocorrelation"
            print(f"  Ljung-Box lag {int(lag_val):>2}: p={row['lb_pvalue']:.4f}  {flag}")
    except Exception as e:
        print(f"  Ljung-Box: {e}")
    if len(residuals) <= 5000:
        stat, p = shapiro(residuals); name = "Shapiro-Wilk"
    else:
        res  = anderson(residuals, dist="norm")
        stat = res.statistic
        p    = 0.05 if res.statistic > res.critical_values[2] else 0.10
        name = "Anderson-Darling"
    flag = "✗ non-normal" if p < 0.05 else "✓ approximately normal"
    print(f"  {name}: stat={stat:.4f}, p≈{p:.4f}  {flag}")

# %%
def run_commodity(comm: str, sub: pd.DataFrame):
    print(f"\n{'='*60}\n  Commodity: {comm}\n{'='*60}")

    sub = sub.sort_values("date").reset_index(drop=True)

    if "split" not in sub.columns:
        raise ValueError("'split' column not found. Expected values: 'train' / 'test'.")

    train_sub = sub[sub["split"] == "train"].reset_index(drop=True)
    test_sub  = sub[sub["split"] == "test"].reset_index(drop=True)
    n_train   = len(train_sub)
    n_test    = len(test_sub)

    if n_train < LOOKBACK + 30:
        print("  !! Not enough training rows — skipping."); return None
    if n_test == 0:
        print("  !! No test rows found — skipping."); return None

    avail    = [c for c in FEATURE_COLS
                if c in sub.columns and train_sub[c].notna().sum() > LOOKBACK]
    all_cols = [TARGET] + [f for f in avail if f != TARGET]
    n_vars   = len(all_cols)
    print(f"  Variates ({n_vars}): {all_cols}")
    print(f"  Train: {train_sub['date'].iloc[0]} -> {train_sub['date'].iloc[-1]} ({n_train} weeks)")
    print(f"  Test:  {test_sub['date'].iloc[0]}  -> {test_sub['date'].iloc[-1]}  ({n_test} weeks)")

    train_data = train_sub[all_cols].copy().ffill().fillna(train_sub[all_cols].mean()).values
    test_data  = test_sub[all_cols].copy().ffill().fillna(train_sub[all_cols].mean()).values
    test_ctx   = np.concatenate([train_data[-LOOKBACK:], test_data], axis=0)

    feat_scaler = StandardScaler().fit(train_data)
    tgt_scaler  = StandardScaler().fit(train_data[:, [0]])
    train_sc    = feat_scaler.transform(train_data)
    test_sc     = feat_scaler.transform(test_ctx)

    n_val = max(int(n_train * 0.15), LOOKBACK + 5)
    n_tr  = n_train - n_val

    train_ds = TSDataset(train_sc[:n_tr],            train_sc[:n_tr, 0],            LOOKBACK, HORIZON)
    val_ds   = TSDataset(train_sc[n_tr - LOOKBACK:], train_sc[n_tr - LOOKBACK:, 0], LOOKBACK, HORIZON)

    if len(train_ds) < 2 or len(val_ds) < 2:
        print("  !! Dataset windows too small — skipping."); return None

    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  drop_last=False)
    val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

    model = SMamba(
        n_vars=n_vars, seq_len=LOOKBACK, horizon=HORIZON,
        d_model=D_MODEL, d_state=D_STATE, d_conv=D_CONV,
        expand=EXPAND,   n_layers=N_LAYERS, patch_len=PATCH_LEN,
        stride=STRIDE,   n_heads=N_HEADS,   dropout=DROPOUT,
    ).to(DEVICE)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"  Patches per window : {model.n_patches}")
    print(f"  Parameters         : {n_params:,}")

    opt       = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=EPOCHS)
    criterion = nn.MSELoss()

    best_val, best_state, patience_cnt = float("inf"), None, 0
    tr_losses, vl_losses               = [], []

    print(f"\n  Training up to {EPOCHS} epochs (patience={PATIENCE})...")
    for epoch in range(1, EPOCHS + 1):
        tl       = train_epoch(model, train_loader, opt, criterion, DEVICE)
        vl, _, _ = eval_epoch(model, val_loader,   criterion, DEVICE)
        scheduler.step()
        tr_losses.append(tl); vl_losses.append(vl)

        if vl < best_val:
            best_val, best_state, patience_cnt = vl, deepcopy(model.state_dict()), 0
        else:
            patience_cnt += 1

        if epoch % 10 == 0 or epoch == 1:
            print(f"  Epoch {epoch:>3}  train={tl:.5f}  val={vl:.5f}  best={best_val:.5f}")
        if patience_cnt >= PATIENCE:
            print(f"  Early stopping at epoch {epoch}"); break

    best_ep = int(np.argmin(vl_losses))
    model.load_state_dict(best_state)

    pred_sc   = walk_forward(model, test_sc, n_test, LOOKBACK, DEVICE)
    pred_orig = tgt_scaler.inverse_transform(pred_sc.reshape(-1, 1)).flatten()
    actual    = test_sub[TARGET].values
    train_orig= train_sub[TARGET].values

    min_len   = min(len(pred_orig), len(actual))
    pred_orig = pred_orig[:min_len]
    actual    = actual[:min_len]

    metrics = compute_metrics(actual, pred_orig, train_orig, f"{comm} — S-Mamba")
    print(f"\n  METRICS:")
    for k, v in metrics.items():
        if k != "model": print(f"    {k:<8}: {v}")

    residuals   = actual - pred_orig
    dates_train = pd.to_datetime(train_sub["date"].values)
    dates_test  = pd.to_datetime(test_sub["date"].values[:min_len])

    print_residual_tests(residuals, f"{comm} — S-Mamba")
    show_training_curve(tr_losses, vl_losses, best_ep, f"{comm} — S-Mamba")
    show_forecast_plot(dates_train, train_orig, dates_test, actual, pred_orig, f"{comm} — S-Mamba")
    show_residual_diagnostics(residuals, pred_orig, f"{comm} — S-Mamba")

    return metrics

# %%
df = (
    pd.read_csv(INPUT_FILE, parse_dates=["date"])
    .sort_values(["commodity", "date"])
    .reset_index(drop=True)
)

commodities = df["commodity"].unique()
print(f"Commodities : {list(commodities)}")
print(f"Device      : {DEVICE}")
print(f"Lookback    : {LOOKBACK} weeks  |  Patch len: {PATCH_LEN}  |  Stride: {STRIDE}")

all_metrics = []
for comm in commodities:
    result = run_commodity(comm, df[df["commodity"] == comm].copy())
    if result:
        all_metrics.append(result)

if all_metrics:
    summary = pd.DataFrame(all_metrics)
    print("\n\n" + "=" * 60)
    print("  FINAL METRICS SUMMARY")
    print("=" * 60)
    print(summary.to_string(index=False))
    summary.to_csv(os.path.join("outputs", "smamba_metrics.csv"), index=False)
    print("\n✅ Done. smamba_metrics.csv saved.")
# Out:
# Commodities : ['Asparagus', 'Beetroot', 'Bulb Onions (Red)', 'Bulb Onions (Yellow)', 'Cabbage', 'Capsicums (Green)', 'Capsicums (Red)', 'Carrots', 'Cooking Apples', 'Cucumbers', 'Curly kale', 'Dessert Apples', 'Leeks', 'Lettuce', 'Pak choi', 'Pears', 'Spring greens', 'Strawberries', 'Tomatoes (Round)', 'Tomatoes (Vine)']
# Device      : cpu
# Lookback    : 52 weeks  |  Patch len: 4  |  Stride: 2
#
# ============================================================
#   Commodity: Asparagus
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2017-06-30 00:00:00 -> 2024-07-12 00:00:00 (117 weeks)
#   Test:  2025-03-03 00:00:00  -> 2025-06-23 00:00:00  (9 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.14358  val=0.97599  best=0.97599
#   Epoch  10  train=0.04947  val=0.76514  best=0.76514
#   Epoch  20  train=0.02100  val=0.89965  best=0.73239
#   Epoch  30  train=0.00861  val=0.80576  best=0.73239
#   Early stopping at epoch 31
#
#   METRICS:
#     RMSE    : 5.1639
#     MAE     : 4.4172
#     MASE    : 2.7223
#     sMAPE   : 33.0874
#     MAPE    : 28.6774
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Asparagus — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : 3.559208
#   SD   : 3.7414
#   Ljung-Box: operands could not be broadcast together with shapes (8,) (20,)
#   Shapiro-Wilk: stat=0.9242, p≈0.4284  ✓ approximately normal
#   Saved all plots for: Asparagus
#
# ============================================================
#   Commodity: Beetroot
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (446 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.84319  val=4.93321  best=4.93321
#   Epoch  10  train=0.08767  val=2.62454  best=2.36554
#   Epoch  20  train=0.06054  val=2.62906  best=0.93599
#   Epoch  30  train=0.04561  val=0.68433  best=0.58158
#   Epoch  40  train=0.03274  val=2.35351  best=0.57935
#   Epoch  50  train=0.03396  val=1.25584  best=0.36335
#   Epoch  60  train=0.03430  val=1.70278  best=0.36335
#   Early stopping at epoch 61
#
#   METRICS:
#     RMSE    : 0.1013
#     MAE     : 0.0792
#     MASE    : 4.191
#     sMAPE   : 9.9769
#     MAPE    : 10.8338
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Beetroot — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.073823
#   SD   : 0.0694
#   Ljung-Box lag 10: p=0.0000  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0000  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9522, p≈0.2246  ✓ approximately normal
#   Saved all plots for: Beetroot
#
# ============================================================
#   Commodity: Bulb Onions (Red)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (426 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.71612  val=1.47254  best=1.47254
#   Epoch  10  train=0.10551  val=0.92384  best=0.92384
#   Epoch  20  train=0.07630  val=0.88968  best=0.79303
#   Epoch  30  train=0.04834  val=0.95924  best=0.76043
#   Epoch  40  train=0.04024  val=0.93160  best=0.76043
#   Early stopping at epoch 46
#
#   METRICS:
#     RMSE    : 0.141
#     MAE     : 0.1134
#     MASE    : 2.7233
#     sMAPE   : 15.3041
#     MAPE    : 16.5021
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Bulb Onions (Red) — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.064036
#   SD   : 0.1256
#   Ljung-Box lag 10: p=0.0065  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0200  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.8660, p≈0.0020  ✗ non-normal
#   Saved all plots for: Bulb Onions (Red)
#
# ============================================================
#   Commodity: Bulb Onions (Yellow)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (439 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.27277  val=0.57350  best=0.57350
#   Epoch  10  train=0.09649  val=0.50894  best=0.21530
#   Epoch  20  train=0.07953  val=0.83818  best=0.21530
#   Early stopping at epoch 22
#
#   METRICS:
#     RMSE    : 0.078
#     MAE     : 0.0613
#     MASE    : 1.6109
#     sMAPE   : 11.5388
#     MAPE    : 10.8101
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Bulb Onions (Yellow) — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.036042
#   SD   : 0.0692
#   Ljung-Box lag 10: p=0.0000  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0000  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9441, p≈0.1407  ✓ approximately normal
#   Saved all plots for: Bulb Onions (Yellow)
#
# ============================================================
#   Commodity: Cabbage
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (447 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.03624  val=6.45241  best=6.45241
#   Epoch  10  train=0.07568  val=1.21324  best=1.21324
#   Epoch  20  train=0.04606  val=0.85076  best=0.57125
#   Epoch  30  train=0.04497  val=1.56352  best=0.52657
#   Epoch  40  train=0.04587  val=1.51930  best=0.52657
#   Early stopping at epoch 46
#
#   METRICS:
#     RMSE    : 0.1516
#     MAE     : 0.1307
#     MASE    : 6.0652
#     sMAPE   : 17.386
#     MAPE    : 19.6206
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Cabbage — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.130668
#   SD   : 0.0768
#   Ljung-Box lag 10: p=0.0000  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0000  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9258, p≈0.0482  ✗ non-normal
#   Saved all plots for: Cabbage
#
# ============================================================
#   Commodity: Capsicums (Green)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2018-07-27 00:00:00 -> 2024-11-08 00:00:00 (120 weeks)
#   Test:  2025-04-14 00:00:00  -> 2025-10-13 00:00:00  (14 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.63896  val=7.45135  best=7.45135
#   Epoch  10  train=0.08989  val=1.54176  best=1.01195
#   Epoch  20  train=0.06332  val=1.18391  best=1.01195
#   Early stopping at epoch 24
#
#   METRICS:
#     RMSE    : 0.3798
#     MAE     : 0.2741
#     MASE    : 1.1159
#     sMAPE   : 18.6703
#     MAPE    : 19.3915
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Capsicums (Green) — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.035284
#   SD   : 0.3782
#   Ljung-Box: operands could not be broadcast together with shapes (13,) (20,)
#   Shapiro-Wilk: stat=0.8425, p≈0.0176  ✗ non-normal
#   Saved all plots for: Capsicums (Green)
#
# ============================================================
#   Commodity: Capsicums (Red)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2017-09-08 00:00:00 -> 2024-11-08 00:00:00 (191 weeks)
#   Test:  2025-04-14 00:00:00  -> 2025-11-10 00:00:00  (14 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=3.36798  val=1.39015  best=1.39015
#   Epoch  10  train=0.10895  val=1.12098  best=1.02689
#   Epoch  20  train=0.07822  val=1.19857  best=1.02689
#   Early stopping at epoch 26
#
#   METRICS:
#     RMSE    : 0.6126
#     MAE     : 0.4671
#     MASE    : 1.9968
#     sMAPE   : 30.0588
#     MAPE    : 32.5477
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Capsicums (Red) — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.158868
#   SD   : 0.5917
#   Ljung-Box: operands could not be broadcast together with shapes (13,) (20,)
#   Shapiro-Wilk: stat=0.6094, p≈0.0000  ✗ non-normal
#   Saved all plots for: Capsicums (Red)
#
# ============================================================
#   Commodity: Carrots
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (438 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.12108  val=2.75270  best=2.75270
#   Epoch  10  train=0.08574  val=0.13746  best=0.13746
#   Epoch  20  train=0.04301  val=0.27675  best=0.13746
#   Epoch  30  train=0.04204  val=0.41121  best=0.12436
#   Epoch  40  train=0.03350  val=0.25316  best=0.12032
#   Epoch  50  train=0.02482  val=0.34257  best=0.12032
#   Early stopping at epoch 54
#
#   METRICS:
#     RMSE    : 0.0541
#     MAE     : 0.0372
#     MASE    : 1.9488
#     sMAPE   : 6.9116
#     MAPE    : 6.9233
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Carrots — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.008179
#   SD   : 0.0535
#   Ljung-Box lag 10: p=0.6594  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.8899  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.8207, p≈0.0003  ✗ non-normal
#   Saved all plots for: Carrots
#
# ============================================================
#   Commodity: Cooking Apples
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (446 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.28721  val=0.14992  best=0.14992
#   Epoch  10  train=0.15641  val=0.04439  best=0.03604
#   Epoch  20  train=0.08948  val=0.06935  best=0.03604
#   Early stopping at epoch 27
#
#   METRICS:
#     RMSE    : 0.1868
#     MAE     : 0.1654
#     MASE    : 2.4271
#     sMAPE   : 13.0906
#     MAPE    : 12.1053
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Cooking Apples — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.165423
#   SD   : 0.0868
#   Ljung-Box lag 10: p=0.0022  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0000  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9621, p≈0.3911  ✓ approximately normal
#   Saved all plots for: Cooking Apples
#
# ============================================================
#   Commodity: Cucumbers
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-05-20 00:00:00 -> 2024-12-20 00:00:00 (342 weeks)
#   Test:  2025-01-20 00:00:00  -> 2025-11-24 00:00:00  (21 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.24218  val=0.91147  best=0.91147
#   Epoch  10  train=0.18387  val=1.01097  best=0.70837
#   Epoch  20  train=0.06523  val=1.04006  best=0.70837
#   Early stopping at epoch 25
#
#   METRICS:
#     RMSE    : 0.2252
#     MAE     : 0.1896
#     MASE    : 1.5024
#     sMAPE   : 17.5563
#     MAPE    : 19.7614
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Cucumbers — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.125279
#   SD   : 0.1872
#   Ljung-Box lag 10: p=0.3470  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.4843  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9679, p≈0.6865  ✓ approximately normal
#   Saved all plots for: Cucumbers
#
# ============================================================
#   Commodity: Curly kale
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2018-11-16 00:00:00 -> 2024-12-20 00:00:00 (301 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.60539  val=0.20864  best=0.20864
#   Epoch  10  train=0.05823  val=0.30288  best=0.20864
#   Epoch  20  train=0.03836  val=0.50761  best=0.20864
#   Early stopping at epoch 21
#
#   METRICS:
#     RMSE    : 0.5642
#     MAE     : 0.5057
#     MASE    : 3.7968
#     sMAPE   : 11.052
#     MAPE    : 11.8639
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Curly kale — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.480094
#   SD   : 0.2963
#   Ljung-Box lag 10: p=0.0001  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0001  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9644, p≈0.4414  ✓ approximately normal
#   Saved all plots for: Curly kale
#
# ============================================================
#   Commodity: Dessert Apples
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-04-08 00:00:00 -> 2024-12-20 00:00:00 (410 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.09640  val=0.33774  best=0.33774
#   Epoch  10  train=0.14594  val=0.83626  best=0.25773
#   Epoch  20  train=0.05577  val=0.39044  best=0.25773
#   Early stopping at epoch 28
#
#   METRICS:
#     RMSE    : 0.093
#     MAE     : 0.0762
#     MASE    : 1.1337
#     sMAPE   : 5.9455
#     MAPE    : 5.7725
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Dessert Apples — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.048876
#   SD   : 0.0792
#   Ljung-Box lag 10: p=0.5758  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.2408  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9718, p≈0.6287  ✓ approximately normal
#   Saved all plots for: Dessert Apples
#
# ============================================================
#   Commodity: Leeks
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (425 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.84677  val=0.68110  best=0.68110
#   Epoch  10  train=0.08770  val=0.61352  best=0.60148
#   Epoch  20  train=0.07649  val=0.74006  best=0.60148
#   Early stopping at epoch 29
#
#   METRICS:
#     RMSE    : 0.1181
#     MAE     : 0.0834
#     MASE    : 1.3512
#     sMAPE   : 5.4424
#     MAPE    : 5.3741
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Leeks — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.023633
#   SD   : 0.1157
#   Ljung-Box lag 10: p=0.0043  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0755  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9272, p≈0.0525  ✓ approximately normal
#   Saved all plots for: Leeks
#
# ============================================================
#   Commodity: Lettuce
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-01-22 00:00:00 -> 2024-12-20 00:00:00 (445 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.79642  val=0.38940  best=0.38940
#   Epoch  10  train=0.10572  val=0.41954  best=0.21950
#   Epoch  20  train=0.06626  val=0.24507  best=0.21741
#   Epoch  30  train=0.04583  val=0.35911  best=0.20297
#   Epoch  40  train=0.03973  val=0.24269  best=0.20297
#   Early stopping at epoch 44
#
#   METRICS:
#     RMSE    : 0.0384
#     MAE     : 0.0307
#     MASE    : 1.347
#     sMAPE   : 4.4258
#     MAPE    : 4.359
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Lettuce — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.008053
#   SD   : 0.0376
#   Ljung-Box lag 10: p=0.9684  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.7532  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9360, p≈0.0874  ✓ approximately normal
#   Saved all plots for: Lettuce
#
# ============================================================
#   Commodity: Pak choi
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2018-11-16 00:00:00 -> 2024-12-20 00:00:00 (305 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.84055  val=0.22727  best=0.22727
#   Epoch  10  train=0.07808  val=0.48179  best=0.18901
#   Epoch  20  train=0.05406  val=0.33748  best=0.18023
#   Epoch  30  train=0.04313  val=0.33987  best=0.18023
#   Early stopping at epoch 34
#
#   METRICS:
#     RMSE    : 0.1557
#     MAE     : 0.124
#     MASE    : 0.9411
#     sMAPE   : 3.4643
#     MAPE    : 3.5542
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Pak choi — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.097082
#   SD   : 0.1217
#   Ljung-Box lag 10: p=0.1797  ✓ no autocorrelation
#   Ljung-Box lag 20: p=0.1127  ✓ no autocorrelation
#   Shapiro-Wilk: stat=0.9875, p≈0.9779  ✓ approximately normal
#   Saved all plots for: Pak choi
#
# ============================================================
#   Commodity: Pears
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-02-26 00:00:00 -> 2024-12-20 00:00:00 (340 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (22 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.84993  val=0.43909  best=0.43909
#   Epoch  10  train=0.13995  val=2.98699  best=0.43909
#   Epoch  20  train=0.06628  val=1.09187  best=0.43909
#   Early stopping at epoch 21
#
#   METRICS:
#     RMSE    : 0.2097
#     MAE     : 0.1602
#     MASE    : 1.5302
#     sMAPE   : 14.4297
#     MAPE    : 16.6087
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Pears — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.090526
#   SD   : 0.1891
#   Ljung-Box lag 10: p=0.0001  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0045  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9749, p≈0.8211  ✓ approximately normal
#   Saved all plots for: Pears
#
# ============================================================
#   Commodity: Spring greens
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2018-11-16 00:00:00 -> 2024-12-20 00:00:00 (302 weeks)
#   Test:  2025-01-20 00:00:00  -> 2026-02-16 00:00:00  (28 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=0.89038  val=0.58482  best=0.58482
#   Epoch  10  train=0.12320  val=0.61714  best=0.26652
#   Epoch  20  train=0.08491  val=0.30946  best=0.26652
#   Early stopping at epoch 24
#
#   METRICS:
#     RMSE    : 0.2619
#     MAE     : 0.2056
#     MASE    : 2.6881
#     sMAPE   : 14.5523
#     MAPE    : 15.7707
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Spring greens — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.076610
#   SD   : 0.2504
#   Ljung-Box lag 10: p=0.0000  ✗ autocorrelated
#   Ljung-Box lag 20: p=0.0000  ✗ autocorrelated
#   Shapiro-Wilk: stat=0.9489, p≈0.1857  ✓ approximately normal
#   Saved all plots for: Spring greens
#
# ============================================================
#   Commodity: Strawberries
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-07-15 00:00:00 -> 2024-12-13 00:00:00 (286 weeks)
#   Test:  2025-04-14 00:00:00  -> 2025-11-24 00:00:00  (17 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.29406  val=0.64936  best=0.64936
#   Epoch  10  train=0.24854  val=0.73175  best=0.62330
#   Epoch  20  train=0.11403  val=0.82580  best=0.62330
#   Early stopping at epoch 26
#
#   METRICS:
#     RMSE    : 1.9985
#     MAE     : 1.5963
#     MASE    : 1.6451
#     sMAPE   : 29.0243
#     MAPE    : 31.1415
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Strawberries — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.016614
#   SD   : 1.9984
#   Ljung-Box: operands could not be broadcast together with shapes (16,) (20,)
#   Shapiro-Wilk: stat=0.9879, p≈0.9967  ✓ approximately normal
#   Saved all plots for: Strawberries
#
# ============================================================
#   Commodity: Tomatoes (Round)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-07-15 00:00:00 -> 2024-11-22 00:00:00 (301 weeks)
#   Test:  2025-04-14 00:00:00  -> 2025-12-08 00:00:00  (18 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=1.59886  val=0.66667  best=0.66667
#   Epoch  10  train=0.17064  val=2.62636  best=0.66667
#   Epoch  20  train=0.07074  val=1.86416  best=0.66667
#   Early stopping at epoch 21
#
#   METRICS:
#     RMSE    : 0.2653
#     MAE     : 0.2234
#     MASE    : 1.1692
#     sMAPE   : 20.5306
#     MAPE    : 23.308
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Tomatoes (Round) — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : -0.115377
#   SD   : 0.2389
#   Ljung-Box: operands could not be broadcast together with shapes (17,) (20,)
#   Shapiro-Wilk: stat=0.9600, p≈0.6019  ✓ approximately normal
#   Saved all plots for: Tomatoes (Round)
#
# ============================================================
#   Commodity: Tomatoes (Vine)
# ============================================================
#   Variates (13): ['target_price', 'api_energy_and_lubricants', 'api_fertilisers_and_soil_improvers', 'api_plant_protection_products', 'api_fresh_fruit', 'api_fresh_vegetables', 'fuel_petrol_price', 'fuel_diesel_price', 'sppi_road_freight', 'shock_2021q4_2023q1', 'post_shock', 'week_sin', 'week_cos']
#   Train: 2016-07-22 00:00:00 -> 2024-12-20 00:00:00 (271 weeks)
#   Test:  2025-04-14 00:00:00  -> 2025-12-22 00:00:00  (19 weeks)
#   Patches per window : 25
#   Parameters         : 384,513
#
#   Training up to 150 epochs (patience=20)...
#   Epoch   1  train=2.65815  val=0.96459  best=0.96459
#   Epoch  10  train=0.22396  val=1.14700  best=0.93688
#   Epoch  20  train=0.08164  val=1.07393  best=0.93688
#   Early stopping at epoch 25
#
#   METRICS:
#     RMSE    : 0.3863
#     MAE     : 0.2153
#     MASE    : 0.7039
#     sMAPE   : 13.1327
#     MAPE    : 12.3396
#
#   ──────────────────────────────────────────────────
#   Residual diagnostics: Tomatoes (Vine) — S-Mamba
#   ──────────────────────────────────────────────────
#   Mean : 0.078062
#   SD   : 0.3783
#   Ljung-Box: operands could not be broadcast together with shapes (18,) (20,)
#   Shapiro-Wilk: stat=0.7067, p≈0.0001  ✗ non-normal
#   Saved all plots for: Tomatoes (Vine)
#
#
# ============================================================
#   FINAL METRICS SUMMARY
# ============================================================
#                          model   RMSE    MAE   MASE   sMAPE    MAPE
#            Asparagus — S-Mamba 5.1639 4.4172 2.7223 33.0874 28.6774
#             Beetroot — S-Mamba 0.1013 0.0792 4.1910  9.9769 10.8338
#    Bulb Onions (Red) — S-Mamba 0.1410 0.1134 2.7233 15.3041 16.5021
# Bulb Onions (Yellow) — S-Mamba 0.0780 0.0613 1.6109 11.5388 10.8101
#              Cabbage — S-Mamba 0.1516 0.1307 6.0652 17.3860 19.6206
#    Capsicums (Green) — S-Mamba 0.3798 0.2741 1.1159 18.6703 19.3915
#      Capsicums (Red) — S-Mamba 0.6126 0.4671 1.9968 30.0588 32.5477
#              Carrots — S-Mamba 0.0541 0.0372 1.9488  6.9116  6.9233
#       Cooking Apples — S-Mamba 0.1868 0.1654 2.4271 13.0906 12.1053
#            Cucumbers — S-Mamba 0.2252 0.1896 1.5024 17.5563 19.7614
#           Curly kale — S-Mamba 0.5642 0.5057 3.7968 11.0520 11.8639
#       Dessert Apples — S-Mamba 0.0930 0.0762 1.1337  5.9455  5.7725
#                Leeks — S-Mamba 0.1181 0.0834 1.3512  5.4424  5.3741
#              Lettuce — S-Mamba 0.0384 0.0307 1.3470  4.4258  4.3590
#             Pak choi — S-Mamba 0.1557 0.1240 0.9411  3.4643  3.5542
#                Pears — S-Mamba 0.2097 0.1602 1.5302 14.4297 16.6087
#        Spring greens — S-Mamba 0.2619 0.2056 2.6881 14.5523 15.7707
#         Strawberries — S-Mamba 1.9985 1.5963 1.6451 29.0243 31.1415
#     Tomatoes (Round) — S-Mamba 0.2653 0.2234 1.1692 20.5306 23.3080
#      Tomatoes (Vine) — S-Mamba 0.3863 0.2153 0.7039 13.1327 12.3396
#
# Done. Files saved:
#    smamba_metrics.csv
#    smamba_training_*.png   — loss curves with early-stopping marker
#    smamba_forecast_*.png   — predicted vs actual on hold-out
#    smamba_residuals_*.png  — 6-panel residual diagnostics
